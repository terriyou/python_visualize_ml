# %%
# 쥬피터노트북 셀 스타일 조절 
from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 100% !important; }</style>"))

# 경고 메세지 숨기기 
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import os
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 퀴즈1 :
#
# YES24 국내도서 종합 베스트셀러 정보 특정 페이지
#
# ```
# 아래의 주소를 참조하여 YES24 종합 베스트셀러의 데이타를 데이타프레임으로 가공하여  csv 파일로 저장하여라.
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=1
#
# 저장되는 요소는? 순위, 책제목, 저자, 출판사, 발행일, 가격, 할인가, URL
#
# ```

# %%
df_book
# Out:
#     순위                        제목  \
# 0    1              트렌드 코리아 2022
# 1    2             갯마을 차차차 포토에세이
# 2    3           설민석의 한국사 대모험 18
# 3    4              달러구트 꿈 백화점 2
# 4    5                 갯마을 차차차 2
# 5    6                 갯마을 차차차 1
# 6    7                달러구트 꿈 백화점
# 7    8              그리스 로마 신화 25
# 8    9  오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 9   10      4~7세 보다 중요한 시기는 없습니다
# 10  11                  그냥 하지 말라
# 11  12           설민석의 세계사 대모험 10
# 12  13                  인생은 실전이다
# 13  14            괴수 8호 4 더블특장판
# 14  15                미드나잇 라이브러리
# 15  16                   불편한 편의점
# 16  17             지금은 나만의 시간입니다
# 17  18                  작별하지 않는다
# 18  19                   공부의 본질
# 19  20                   초등 사자소학
#
#                                                    저자              출판사  \
# 0   김난도,전미영,최지혜,이향은,이준영,이수진,서유현,권정윤,한다혜,서울대학교 생활과학...             미래의창
# 1                                          스튜디오드래곤 제작           북로그컴퍼니
# 2                           설민석,스토리박스 글/정현희 그림/강석화 감수             아이휴먼
# 3                                               이미예 저            팩토리나인
# 4                                               신하은 저           북로그컴퍼니
# 5                                               신하은 저           북로그컴퍼니
# 6                                               이미예 저            팩토리나인
# 7                                  박시연 글/최우빈 그림/김헌 감수              아울북
# 8                                     이치조 미사키 저/권영주 역               모모
# 9                                               이임숙 저            카시오페아
# 10                                              송길영 저              북스톤
# 11                            설민석,김정욱 글/박성일 그림/원태준 감수             단꿈아이
# 12                                    신영준,주언규(신사임당) 저            상상스퀘어
# 13                                 마츠모토 나오야 글그림/유유리 역  서울미디어코믹스(서울문화사)
# 14                                     매트 헤이그 저/노진선 역            인플루엔셜
# 15                                              김호연 저            나무옆의자
# 16                                              김유진 저             토네이도
# 17                                               한강 저             문학동네
# 18                                              이윤규 저              빅피시
# 19                                       송재환 글/인호빵 그림           위즈덤하우스
#
#           발행일       가격      할인가                                       URL
# 0   2021년 10월  18,000원  16,200원  http://yes24.com/Product/Goods/103737985
# 1   2021년 11월  28,000원  25,200원  http://yes24.com/Product/Goods/104255924
# 2   2021년 10월  12,000원  10,800원  http://yes24.com/Product/Goods/104122285
# 96                                   이와이 도시오 글그림/김숙 역     북뱅크  2021년 08월
# 97                                               연정 저     발코니  2020년 04월
# 98                                               나씨 저   경향미디어  2021년 09월
# 99                                      칼 세이건 저/홍승수 역  사이언스북스  2006년 12월
#
#          가격      할인가                                       URL
# 0   18,000원  16,200원  http://yes24.com/Product/Goods/103737985
# 1   28,000원  25,200원  http://yes24.com/Product/Goods/104255924
# 2   12,000원  10,800원  http://yes24.com/Product/Goods/104122285
# 3   13,800원  12,420원  http://yes24.com/Product/Goods/102789938
# 4   18,000원  16,200원  http://yes24.com/Product/Goods/104105224
# ..      ...      ...                                       ...
# 95  12,000원  10,800원   http://yes24.com/Product/Goods/72158875
# 96  13,000원  11,700원  http://yes24.com/Product/Goods/102836978
# 97  10,900원   9,810원   http://yes24.com/Product/Goods/89897814
# 98  15,000원  13,500원  http://yes24.com/Product/Goods/103505075
# 99  18,500원  16,650원    http://yes24.com/Product/Goods/2312211
#
# [100 rows x 8 columns]

# %% [markdown]
# # 퀴즈3
#
# YES24 국내도서 종합 베스트셀러 정보 모든 페이지
#
# ```
# 아래의 주소를 참조하여 YES24 종합 베스트셀러의 모든 페이지가
# 데이타프레임으로 출력되고 csv로 저장되도록한다.
#
# 참조 URL :
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=1
#
# 저장되는 요소는? 순위, 책제목, 저자, 출판사, 발행일, 가격, 할인가, URL
#
# ```

# %%
df_book = pd.DataFrame(book_list, 
                       columns=['순위', '제목','저자','출판사','발행일', '가격', '할인가', 'URL'])

# %%
df_book.shape
# Out:
# (998, 8)

# %%
df_book.to_csv('output/yes24bestseller_202111_29.csv', index=False)

# %%
df_book
# Out:
#       순위                             제목  \
# 0      1                    투자는 디테일에 있다
# 1      2                   트렌드 코리아 2022
# 2      3                     거꾸로 읽는 세계사
# 3      4             원피스 ONE PIECE 100
# 4      5                    사랑해 사랑해 사랑해
# ..   ...                            ...
# 993  994          2022 오정화 회계학 회계 1000제
# 994  995                     중학교 입학 가이드
# 995  996         2022 YES THE 노동법 기출문제집
# 996  997  2022 간호사 국가고시 초단기완성 파이널 핵심요약집
# 997  998            큰별쌤 최태성의 별★별 한국사 세트
#
#                                                     저자           출판사  \
# 0                                                김정환 저           부케이
# 1    김난도,전미영,최지혜,이향은,이준영,이수진,서유현,권정윤,한다혜,서울대학교 생활과학...          미래의창
# 2                                                유시민 저           돌베개
# 3                                         오다 에이이치로 글그림            대원
# 4                    버나뎃 로제티 슈스탁 글/캐롤라인 제인 처치 그림/신형건 역          보물창고
# ..                                                 ...           ...
# 993                                             오정화 편저  메가스터디교육(공무원)
# 994                                              배혜림 저         한빛라이프
# 995                                            김에스더 편저         서울고시각
# 996                                      주선희,간호수험연구소 저           홍지문
# 997                                   최태성 글/김규택,김선배 그림        위즈덤하우스
#
#            발행일       가격      할인가                                       URL
# 0    2021년 12월  18,000원  16,200원  http://yes24.com/Product/Goods/105261388
# 1    2021년 10월  18,000원  16,200원  http://yes24.com/Product/Goods/103737985
# 2    2021년 10월  17,500원  15,750원  http://yes24.com/Product/Goods/104409067
# 3    2021년 12월   5,500원   4,950원  http://yes24.com/Product/Goods/105245181
# 4    2021년 12월  11,800원  11,210원  http://yes24.com/Product/Goods/105163956
# ..         ...      ...      ...                                       ...
# 993  2021년 11월  47,000원  42,300원  http://yes24.com/Product/Goods/105104554
# 994  2021년 11월  16,500원  14,850원  http://yes24.com/Product/Goods/105019734
# 995  2022년 01월  17,000원  15,300원  http://yes24.com/Product/Goods/105016143
# 996  2021년 10월  25,000원  22,500원  http://yes24.com/Product/Goods/104721572
# 997  2021년 10월  80,000원  72,000원  http://yes24.com/Product/Goods/104235598
#
# [998 rows x 8 columns]

# %%
# 관련 모듈 임포트
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 1) 한페이지의 책 정보

# %%
# response 객체 => html 페이지

url = 'http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=1'
res = requests.get(url)
html_str = res.text
res
# Out:
# <Response [200]>

# %%
# soup 객체화 => 파싱
soup = BeautifulSoup(html_str, 'html.parser')
# soup

# %%
# 필터링 => 반복되는 요소의 선택자를 추출 
# td.goodsTxtInfo => td 태그에 적용된 goodsTxtInfo 클래스 
# td_list = soup.select('td.goodsTxtInfo')
td_list = soup.select('.goodsTxtInfo')
len(td_list)
# Out:
# 20

# %% [raw]
# <td class="goodsTxtInfo">
# 			<p>[도서]   <a href="/Product/Goods/105261388">투자는 디테일에 있다</a> : 슈퍼개미 김정환의 투자 바이블
#
#             <a href="/Product/Goods/105261388" target="_blank"><img src="http://image.yes24.com/sysimage/bestseller/b_newwin.gif" alt="새창"></a></p>
#
#
# 			<div class="aupu">
#                 <a href="http://www.yes24.com/SearchCorner/Result?domain=ALL&amp;author_yn=Y&amp;query=&amp;auth_no=367712" target="_blank">김정환</a> 저
#
#
#                     | <a href="http://www.yes24.com/SearchCorner/Result?domain=ALL&amp;company_yn=Y&amp;query=%ba%ce%c4%c9%c0%cc">부케이</a>
#
#                     | 2021년 12월
#
#             </div>
#
#                     <p>18,000원 →<span class="priceB">16,200원</span>(<span class="price">10%</span> 할인) | YES포인트 <span class="price">900원</span>(<span class="price">5%</span> 지급)</p>
#
# 			<p class="review">회원리뷰 (<a href="/Product/Goods/105261388?reviewYn=Y">3개</a>) | 내용 <img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOff.gif"> | 편집구성 <img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOn.gif"><img src="http://image.yes24.com/sysimage/interface/StarOff.gif">
#
# 			</p>
# 			<p>
#
# <link rel="stylesheet" type="text/css" href="/resource/css/popup.css">
#
#         지금 주문하면 <strong>오늘(12/1, 수)</strong> 도착예정
#     </p>
#
# 			<p class="ordNum" style="">
# 				수량 <input type="text" name="ORD_GOODS_CNT" value="1" readonly="">
# 				<img src="http://image.yes24.com/sysimage/detailN/b_numUp.gif" alt="" class="numUp" onclick="yes24GU.upOrderCount(0)">
# 				<img src="http://image.yes24.com/sysimage/detailN/b_numDown.gif" alt="" class="numDown" onclick="yes24GU.downOrderCount(0)">
# 			</p>
#
# 			<p>
# 			<a href="/24/Category/More/001014?ElemNo=13&amp;ElemSeq=1&amp;Gcode=000_030_001"><img src="http://image.yes24.com/sysimage/categoryN/i_today.gif" alt="오늘의 책" title="오늘의 책"></a>&nbsp;
#
# 			</p>
# 		</td>

# %%
# 책 한권의 정보 확인 
base_url = 'http://yes24.com'

title = td_list[0].select_one('a').text
# url = base_url + td_list[0].select_one('a').get('href')
url = base_url + td_list[0].select_one('a')['href']

# temp = td_list[0].select_one('div.aupu').text
# 김정환 저 | 부케이 | 2021년 12월
temp = td_list[0].select_one('div.aupu').text.split('| ')
# print(temp)
# print(temp[0]) # 저자 
# print(temp[1]) #  출판사
# print(temp[2]) #  발행일
# print('='*50)
writer = temp[0].strip().split('\r\n')[0].strip()
publisher = temp[1].strip()
published_date = temp[2].strip()

# 가격, 할인가 
'''
<p>18,000원 →<span class="priceB">16,200원</span>(<span class="price">10%</span> 할인) | YES포인트 <span class="price">900원</span>(<span class="price">5%</span> 지급)</p>
'''
# print(td_list[0].select('p')[1])
price = td_list[0].select('p')[1].text.split()[0]
discount_price = td_list[0].select_one('span.priceB').text

print('='*50)
print('책제목 => ', title)
print('URL => ', url)
print('저자 => ', writer)
print('출판사 => ', publisher)
print('출판일 => ', published_date)
print('가격 => ', price)
print('할인가 => ', discount_price)
# Out:
# ==================================================
# 책제목 =>  투자는 디테일에 있다
# URL =>  http://yes24.com/Product/Goods/105261388
# 저자 =>  김정환 저
# 출판사 =>  부케이
# 출판일 =>  2021년 12월
# 가격 =>  18,000원
# 할인가 =>  16,200원

# %%
# 2차원 리스트로 저장 후 데이타프레임으로 변경 
base_url = 'http://yes24.com'
book_list = []
rank = 0
for td in td_list:
    rank += 1
    title = td.select_one('a').text
    url = base_url + td.select_one('a').get('href')
    temp = td.select_one('div.aupu').text.split('| ')
    writer = temp[0].strip().split('\r\n')[0].strip()
    publisher = temp[1].strip()
    published_date = temp[2].strip()
    price = td.select('p')[1].text.split()[0]
    discount_price = td.select_one('span.priceB').text
    # 2차원 리스트로 추가 
    book_list.append([rank, title, writer, publisher, published_date, price, discount_price, url])

df_book = pd.DataFrame(book_list, 
                       columns=['순위', '제목','저자','출판사','발행일', '가격', '할인가', 'URL'])

# %%
df_book
# Out:
#     순위                            제목  \
# 0    1                   투자는 디테일에 있다
# 1    2                  트렌드 코리아 2022
# 2    3                     거인의 포트폴리오
# 3    4                   사랑해 사랑해 사랑해
# 4    5                    거꾸로 읽는 세계사
# 5    6                  흔한남매 겨울밤 대소동
# 14  2021년 11월  16,000원  14,400원  http://yes24.com/Product/Goods/104866527
# 15  2021년 09월  18,000원  16,200원  http://yes24.com/Product/Goods/103417076
# 16  2021년 11월  12,000원  10,800원  http://yes24.com/Product/Goods/104985558
# 17  2019년 01월  16,000원  14,400원   http://yes24.com/Product/Goods/67543979
# 18  2021년 04월  14,000원  12,600원   http://yes24.com/Product/Goods/99308021
# 19  2021년 11월  16,000원  14,400원  http://yes24.com/Product/Goods/104647964

# %% [markdown]
# ## (2) 범위내의 페이지 정보를 데이타프레임으로 출력하는 함수 생성후 확인하기

# %%
def book_print(start=1, end=1):
    
    base_url = 'http://yes24.com'
    book_list = []
    rank = 0
    
    for i in range(start, end+1):
        # 주소 생성 
        url = 'http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=' + str(i)
        print(url)

        res = requests.get(url)
        html_str = res.text

        soup = BeautifulSoup(html_str, 'html.parser')
        td_list = soup.select('td.goodsTxtInfo')
#         len(td_list)


        for td in td_list:
            rank += 1
            title = td.select_one('a').text
            url = base_url + td.select_one('a').get('href')
            temp = td.select_one('div.aupu').text.split('| ')
            writer = temp[0].strip().split('\r\n')[0].strip()
            publisher = temp[1].strip()
            published_date = temp[2].strip()
            price = td.select('p')[1].text.split()[0]
            discount_price = td.select_one('span.priceB').text
            book_list.append([rank, title, writer, publisher, published_date, price, discount_price, url])
    
    
    
    df_book = pd.DataFrame(book_list, 
                       columns=['순위', '제목','저자','출판사','발행일', '가격', '할인가', 'URL'])    

    return df_book

# %%
# 페이지를 지정하지 않고 호출시 1페이지만 출력 
book_print()
# Out:
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=1
#     순위                            제목  \
# 0    1                   투자는 디테일에 있다
# 1    2                  트렌드 코리아 2022
# 2    3                     거인의 포트폴리오
# 3    4                   사랑해 사랑해 사랑해
# 4    5                    거꾸로 읽는 세계사
# 5    6                  흔한남매 겨울밤 대소동
# 6    7                  달러구트 꿈 백화점 2
# 7    8                      그냥 하지 말라
# 8    9            Go Go 카카오프렌즈 22 페루
# 9   10                    미드나잇 라이브러리
# 10  11                    달러구트 꿈 백화점
# 11  12              흔한남매 과학 탐험대 3 인체
# 12  13            원피스 ONE PIECE 100
# 13  14  [예스리커버] 4~7세 보다 중요한 시기는 없습니다
# 14  15              웰씽킹 WEALTHINKING
# 15  16                      NFT 레볼루션
# 16  17              이상한 과자 가게 전천당 12
# 17  18                       오은영의 화해
# 18  19                       불편한 편의점
# 19  20                     오십에 읽는 논어
#
#                                                    저자               출판사  \
# 0                                               김정환 저               부케이
# 1   김난도,전미영,최지혜,이향은,이준영,이수진,서유현,권정윤,한다혜,서울대학교 생활과학...              미래의창
# 2                                               강환국 저              페이지2
# 3                   버나뎃 로제티 슈스탁 글/캐롤라인 제인 처치 그림/신형건 역              보물창고
# 4                                               유시민 저               돌베개
# 5                       흔한남매 원저/한바리 글/유난희 그림/흔한컴퍼니 감수           미래엔아이세움
# 6                                               이미예 저             팩토리나인
# 0                                               김정환 저            부케이
# 1   김난도,전미영,최지혜,이향은,이준영,이수진,서유현,권정윤,한다혜,서울대학교 생활과학...           미래의창
# 2                                               강환국 저           페이지2
# 3                   버나뎃 로제티 슈스탁 글/캐롤라인 제인 처치 그림/신형건 역           보물창고
# 4                                               유시민 저            돌베개
# ..                                                ...            ...
# 95                                              박성혁 저           다산북스
# 96                                     한국경제신문 특별취재팀 저  한국경제신문사(한경비피)
# 97                          베르나르 베르베르 저/이세욱,임호경,전미연 역           열린책들
# 98                                         최나야,정수정 공저            로그인
# 99                                              김도윤 저           북로망스
#
#           발행일       가격      할인가                                       URL
# 0   2021년 12월  18,000원  16,200원  http://yes24.com/Product/Goods/105261388
# 1   2021년 10월  18,000원  16,200원  http://yes24.com/Product/Goods/103737985
# 2   2021년 11월  18,000원  16,200원  http://yes24.com/Product/Goods/104988500
# 3   2021년 12월  11,800원  11,210원  http://yes24.com/Product/Goods/105163956
# 4   2021년 10월  17,500원  15,750원  http://yes24.com/Product/Goods/104409067
# ..        ...      ...      ...                                       ...
# 95  2020년 07월  15,000원  13,500원   http://yes24.com/Product/Goods/16384156
# 96  2021년 11월  18,000원  16,200원  http://yes24.com/Product/Goods/105135781
# 97  2021년 11월  17,800원  16,020원  http://yes24.com/Product/Goods/104647674
# 98  2021년 10월  17,800원  16,020원  http://yes24.com/Product/Goods/104470604
# 99  2021년 08월  16,000원  14,400원  http://yes24.com/Product/Goods/103337443
#
# [100 rows x 8 columns]

# %% [markdown]
# # (3)전체 페이지 csv 파일로 저장하기

# %%
# false 조건 => 0, [], (), {}, ''

# %%
base_url = 'http://yes24.com'
book_list = []
rank = 0
page = 0
    
while True:
    page += 1
    url = 'http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=' + str(page)
    print(url)

    res = requests.get(url)
    html_str = res.text

    soup = BeautifulSoup(html_str, 'html.parser')
    td_list = soup.select('td.goodsTxtInfo')
    print(len(td_list))

    # 책 정보가 있다면 
    if td_list: 
        for td in td_list:
            rank += 1
            title = td.select_one('a').text
            url = base_url + td.select_one('a').get('href')
            temp = td.select_one('div.aupu').text.split('| ')
            writer = temp[0].strip().split('\r\n')[0].strip()
            publisher = temp[1].strip()
            published_date = temp[2].strip()
            price = td.select('p')[1].text.split()[0]
            discount_price = td.select_one('span.priceB').text
            book_list.append([rank, title, writer, publisher, published_date, price, discount_price, url])
    else:
        break

print('데이타 저장 종료')
# Out:
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=1
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=2
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=3
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=4
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=5
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=6
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=7
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=8
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=9
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=10
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=11
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=12
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=13
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=14
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=15
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=16
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=17
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=18
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=19
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=20
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=21
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=22
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=23
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=24
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=25
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=26
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=27
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=28
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=29
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=30
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=31
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=32
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=33
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=34
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=35
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=36
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=37
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=38
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=39
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=40
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=41
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=42
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=43
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=44
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=45
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=46
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=47
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=48
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=49
# 20
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=50
# 19
# http://www.yes24.com/24/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber=51
# 0
# 데이타 저장 종료

# %%
df_book = pd.DataFrame(book_list, 
                       columns=['순위', '제목','저자','출판사','발행일', '가격', '할인가', 'URL'])

# %%
df_book.shape
# Out:
# (999, 8)

# %%
df_book.head()
# Out:
#    순위            제목                                                 저자   출판사  \
# 0   1   투자는 디테일에 있다                                              김정환 저   부케이
# 1   2  트렌드 코리아 2022  김난도,전미영,최지혜,이향은,이준영,이수진,서유현,권정윤,한다혜,서울대학교 생활과학...  미래의창
# 2   3     거인의 포트폴리오                                              강환국 저  페이지2
# 3   4   사랑해 사랑해 사랑해                  버나뎃 로제티 슈스탁 글/캐롤라인 제인 처치 그림/신형건 역  보물창고
# 4   5    거꾸로 읽는 세계사                                              유시민 저   돌베개
#
#          발행일       가격      할인가                                       URL
# 0  2021년 12월  18,000원  16,200원  http://yes24.com/Product/Goods/105261388
# 1  2021년 10월  18,000원  16,200원  http://yes24.com/Product/Goods/103737985
# 2  2021년 11월  18,000원  16,200원  http://yes24.com/Product/Goods/104988500
# 3  2021년 12월  11,800원  11,210원  http://yes24.com/Product/Goods/105163956
# 4  2021년 10월  17,500원  15,750원  http://yes24.com/Product/Goods/104409067

# %%
df_book.tail()
# Out:
#       순위                    제목              저자            출판사        발행일  \
# 994  995           슬픈 세상의 기쁜 말           정혜윤 저             위고  2021년 08월
# 995  996              메타버스의 시대           이시한 저           다산북스  2021년 08월
# 996  997  절대로 누르면 안 돼! 크리스마스에도  빌 코터 글그림/이정훈 역            북뱅크  2020년 12월
# 997  998  이상하게 돈 걱정 없는 사람들의 비밀  혼다 고이치 저/이주희 역  동양북스(동양books)  2021년 11월
# 998  999          무기력이 무기력해지도록           한창수 저   알에이치코리아(RHK)  2021년 08월
#
#           가격      할인가                                       URL
# 994  16,000원  14,400원  http://yes24.com/Product/Goods/103028898
# 995  17,000원  15,300원  http://yes24.com/Product/Goods/103302716
# 996  12,000원  10,800원   http://yes24.com/Product/Goods/95149669
# 997  13,800원  12,420원  http://yes24.com/Product/Goods/104801308
# 998  16,000원  14,400원  http://yes24.com/Product/Goods/103167335

# %%
df_book.to_csv('output/yes24bestseller_202112_01.csv', index=False, encoding='utf-8')

# %%
ls output
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 2819-FF50
#
#  C:\workspace211123\output 디렉터리
#
# 2021-12-01  오전 09:51    <DIR>          .
# 2021-12-01  오전 09:51    <DIR>          ..
# 2021-11-29  오전 11:44             2,096 alexa.csv
# 2021-11-29  오후 04:49            21,104 blog_오징어게임.csv
# 2021-11-26  오후 01:55            40,508 df_gap1.csv
# 2021-11-29  오후 02:40            14,184 kid.csv
# 2021-11-24  오후 02:37             1,972 rating100.csv
# 2021-11-30  오후 10:55           162,461 yes24bestseller_202111_30.csv
# 2021-12-01  오전 09:51           162,020 yes24bestseller_202112_01.csv
# 2021-11-26  오후 05:07               240 평균분양가격_서울인천경기.csv
#                8개 파일             404,585 바이트
#                2개 디렉터리  66,659,491,840 바이트 남음
